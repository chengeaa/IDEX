# %%
from pandas import *
from numpy import *

# %%
all_donations =read_csv("7yr.csv")

# %%
all_donations
# Out:
#                                            Campaign Name  \
# 0      #DiasporansGive - Africans in the Diaspora (Ai...
# 1      #DiasporansGive - Africans in the Diaspora (Ai...
# 2      #DiasporansGive - Africans in the Diaspora (Ai...
# 3      #DiasporansGive - Africans in the Diaspora (Ai...
# 4      #DiasporansGive - Africans in the Diaspora (Ai...
# 5      #DiasporansGive - Africans in the Diaspora (Ai...
# 6      #DiasporansGive - Africans in the Diaspora (Ai...
# 7      #DiasporansGive - Africans in the Diaspora (Ai...
# 8      #DiasporansGive - Africans in the Diaspora (Ai...
# 9      #DiasporansGive - Africans in the Diaspora (Ai...
# 10     #DiasporansGive - Africans in the Diaspora (Ai...
# 11     #DiasporansGive - Africans in the Diaspora (Ai...
# 12     #DiasporansGive - Africans in the Diaspora (Ai...
# 13     #DiasporansGive - Africans in the Diaspora (Ai...
# 14     #DiasporansGive - Africans in the Diaspora (Ai...
# ...
